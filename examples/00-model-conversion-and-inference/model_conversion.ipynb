# %% [markdown]
# # Model Conversion
#
# **To run this file requires PyTorch LTS 1.8 and TorchVision**
#
# This file converts the pretrained ResNet50 PyTorch model
# into either a Caffe model or an ONNX model.

# %%
target_model_type = "onnx"
# or convert the model to caffe
# target_model_type = "caffe"

# %%
image_path = "data/drum.jpg"
labels_path = "data/imagenet_classes.txt"
expected_label = "drum"

tmp_model_base_name = "tmp/model"

# %% [markdown]
# Test image:
# ![drum](data/drum.jpg)

# %%
from pathlib import Path
from PIL import Image
import numpy as np
import torch
import torchvision
from torchvision.models import resnet50

from nart.tools.pytorch import export_onnx, convert_v2
from nart.tools.pytorch.module_utils import convert_mode

# %%
torch.__version__, torchvision.__version__
# Out:
# ('1.8.1', '0.2.1')

# %%
Path(tmp_model_base_name).parent.mkdir(parents=True, exist_ok=True)

# %%
# read labels
with open(labels_path) as f:
    labels = list(map(str.strip, f.readlines()))

# %%
# prepare the input data
img = Image.open(image_path).resize((256, 256)).crop((16, 16, 240, 240))
input_data = np.array(img).transpose(2, 0, 1).astype(np.float32) / 255.0
input_data -= np.array([0.485, 0.456, 0.406]).reshape((3, 1, 1))
input_data /= np.array([0.229, 0.224, 0.225]).reshape((3, 1, 1))
input_data = input_data.reshape((1, 3, 224, 224))

# %%
input_data = torch.from_numpy(input_data)
print(input_data.shape)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
# use the pretrained model, download it if it does not exists
model = resnet50(pretrained=True)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# verify the predicted result
output_data = model(input_data)
predict_res = output_data.argmax(axis=1)
predict_labels = [labels[i] for i in predict_res.tolist()]
print(predict_labels)
assert predict_labels[0] == expected_label
# Out:
# ['drum']

# %%
if target_model_type.lower() == "onnx":
    convert_func = export_onnx
else:
    convert_func = convert_v2

# %%
# convert the model
with convert_mode():
    convert_func(
        model,
        [tuple(input_data.shape)],
        filename=tmp_model_base_name,
        log=True,
        verbose=True,
        cloze=False,
    )
# Out:
# ====convert: start of pytorch-to-onnx export
# /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/nart_py-1.2.14.dev0-py3.7.egg/nart/tools/pytorch/module_utils/pytorch1_8/symbolic_opset9.py:876: UserWarning: Pooling with count_include_pad=True is not supported in caffe.
#   warnings.warn("Pooling with count_include_pad=True is not supported in caffe.")
# graph(%input.1 : Float(1, 3, 224, 224, strides=[150528, 50176, 224, 1], requires_grad=1, device=cpu),
#       %fc.weight : Float(1000, 2048, strides=[2048, 1], requires_grad=1, device=cpu),
#       %fc.bias : Float(1000, strides=[1], requires_grad=1, device=cpu),
#       %498 : Float(64, 3, 7, 7, strides=[147, 49, 7, 1], requires_grad=0, device=cpu),
#       %499 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %501 : Float(64, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %502 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %504 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %505 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %507 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %508 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %510 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %511 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %513 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %514 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %516 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %517 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %519 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %520 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %522 : Float(64, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %523 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %525 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cpu),
#       %526 : Float(64, strides=[1], requires_grad=0, device=cpu),
#       %528 : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cpu),
#       %529 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %531 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %532 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %534 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %535 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %537 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %538 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %540 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %541 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %543 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %544 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %546 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %547 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %549 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %550 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %552 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %553 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %555 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %556 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %558 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %559 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %561 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %562 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %564 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cpu),
#       %565 : Float(128, strides=[1], requires_grad=0, device=cpu),
#       %567 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cpu),
#       %568 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %570 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %571 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %573 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %574 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %576 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %577 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %579 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %580 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %582 : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %583 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %585 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %586 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %588 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %589 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %591 : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %592 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %594 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %595 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %597 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %598 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %600 : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %601 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %603 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %604 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %606 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %607 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %609 : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %610 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %612 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %613 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %615 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %616 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %618 : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %619 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %621 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cpu),
#       %622 : Float(256, strides=[1], requires_grad=0, device=cpu),
#       %624 : Float(1024, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cpu),
#       %625 : Float(1024, strides=[1], requires_grad=0, device=cpu),
#       %627 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %628 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %630 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %631 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %633 : Float(2048, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %634 : Float(2048, strides=[1], requires_grad=0, device=cpu),
#       %636 : Float(2048, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cpu),
#       %637 : Float(2048, strides=[1], requires_grad=0, device=cpu),
#       %639 : Float(512, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %640 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %642 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %643 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %645 : Float(2048, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %646 : Float(2048, strides=[1], requires_grad=0, device=cpu),
#       %648 : Float(512, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cpu),
#       %649 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %651 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=0, device=cpu),
#       %652 : Float(512, strides=[1], requires_grad=0, device=cpu),
#       %654 : Float(2048, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cpu),
#       %655 : Float(2048, strides=[1], requires_grad=0, device=cpu)):
#   %497 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%input.1, %498, %499)
#   %323 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=1, device=cpu) = onnx::Relu(%497) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %324 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%323) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:659:0
#   %500 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%324, %501, %502)
#   %327 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%500) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %503 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%327, %504, %505)
#   %330 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%503) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %506 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%330, %507, %508)
#   %509 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%324, %510, %511)
#   %335 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Add(%506, %509) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %336 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%335)
#   %512 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%336, %513, %514)
#   %339 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%512) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %515 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%339, %516, %517)
#   %342 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%515) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %518 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%342, %519, %520)
#   %345 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Add(%518, %336) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %346 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%345)
#   %521 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%346, %522, %523)
#   %349 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%521) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %524 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%349, %525, %526)
#   %352 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%524) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %527 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%352, %528, %529)
#   %355 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Add(%527, %346) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %356 : Float(1, 256, 56, 56, strides=[802816, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%355) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %530 : Float(1, 128, 56, 56, strides=[401408, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%356, %531, %532)
#   %359 : Float(1, 128, 56, 56, strides=[401408, 3136, 56, 1], requires_grad=1, device=cpu) = onnx::Relu(%530) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %533 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%359, %534, %535)
#   %362 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%533) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %536 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%362, %537, %538)
#   %539 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%356, %540, %541)
#   %367 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%536, %539) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %368 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%367)
#   %542 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%368, %543, %544)
#   %371 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%542) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %545 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%371, %546, %547)
#   %374 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%545) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %548 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%374, %549, %550)
#   %377 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%548, %368) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %378 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%377)
#   %551 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%378, %552, %553)
#   %381 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%551) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %554 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%381, %555, %556)
#   %384 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%554) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %557 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%384, %558, %559)
#   %387 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%557, %378) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %388 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%387)
#   %560 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%388, %561, %562)
#   %391 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%560) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %563 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%391, %564, %565)
#   %394 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%563) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %566 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%394, %567, %568)
#   %397 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Add(%566, %388) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %398 : Float(1, 512, 28, 28, strides=[401408, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%397) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %569 : Float(1, 256, 28, 28, strides=[200704, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%398, %570, %571)
#   %401 : Float(1, 256, 28, 28, strides=[200704, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu(%569) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %572 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%401, %573, %574)
#   %404 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%572) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %575 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%404, %576, %577)
#   %578 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%398, %579, %580)
#   %409 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%575, %578) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %410 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%409)
#   %581 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%410, %582, %583)
#   %413 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%581) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %584 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%413, %585, %586)
#   %416 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%584) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %587 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%416, %588, %589)
#   %419 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%587, %410) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %420 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%419)
#   %590 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%420, %591, %592)
#   %423 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%590) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %593 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%423, %594, %595)
#   %426 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%593) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %596 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%426, %597, %598)
#   %429 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%596, %420) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %430 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%429)
#   %599 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%430, %600, %601)
#   %433 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%599) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %602 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%433, %603, %604)
#   %436 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%602) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %605 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%436, %606, %607)
#   %439 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%605, %430) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %440 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%439)
#   %608 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%440, %609, %610)
#   %443 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%608) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %611 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%443, %612, %613)
#   %446 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%611) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %614 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%446, %615, %616)
#   %449 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%614, %440) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %450 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%449)
#   %617 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%450, %618, %619)
#   %453 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%617) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %620 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%453, %621, %622)
#   %456 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%620) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %623 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%456, %624, %625)
#   %459 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Add(%623, %450) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %460 : Float(1, 1024, 14, 14, strides=[200704, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%459) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %626 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%460, %627, %628)
#   %463 : Float(1, 512, 14, 14, strides=[100352, 196, 14, 1], requires_grad=1, device=cpu) = onnx::Relu(%626) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %629 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%463, %630, %631)
#   %466 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%629) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %632 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%466, %633, %634)
#   %635 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%460, %636, %637)
#   %471 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Add(%632, %635) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %472 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%471)
#   %638 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%472, %639, %640)
#   %475 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%638) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %641 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%475, %642, %643)
#   %478 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%641) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %644 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%478, %645, %646)
#   %481 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Add(%644, %472) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %482 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%481)
#   %647 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%482, %648, %649)
#   %485 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%647) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %650 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%485, %651, %652)
#   %488 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%650) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %653 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%488, %654, %655)
#   %491 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Add(%653, %482) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:90:0
#   %492 : Float(1, 2048, 7, 7, strides=[100352, 49, 7, 1], requires_grad=1, device=cpu) = onnx::Relu(%491) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1204:0
#   %493 : Float(1, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, kernel_shape=[7, 7], pads=[0, 0, 0, 0], strides=[1, 1]](%492) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/modules/pooling.py:616:0
#   %494 : Long(2, strides=[1], device=cpu) = onnx::Constant[value= 1 -1 [ CPULongType{2} ]]()
#   %495 : Float(1, 2048, strides=[2048, 1], requires_grad=1, device=cpu) = onnx::Reshape(%493, %494) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torchvision/models/resnet.py:150:0
#   %496 : Float(1, 1000, strides=[1000, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%495, %fc.weight, %fc.bias) # /home/chielo/miniconda3/envs/nart/lib/python3.7/site-packages/torch/nn/functional.py:1753:0
#   return (%496)
# ====convert: end of pytorch-to-onnx export
